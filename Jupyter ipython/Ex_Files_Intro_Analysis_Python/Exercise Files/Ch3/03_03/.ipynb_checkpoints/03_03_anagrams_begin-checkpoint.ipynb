# %%
word = open('words','r')

# %%
word
# Out:
# <_io.TextIOWrapper name='words' mode='r' encoding='cp936'>

# %%
wordlist = word.readlines()

# %%
wordlist[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n']

# %%
len(wordlist)
# Out:
# 235886

# %%
'Aaron\n'.strip()
# Out:
# 'Aaron'

# %%
'Aaron'.lower()
# Out:
# 'aaron'

# %%
wordclean = [word.strip().lower() for word in wordlist]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordunique = list(set(wordclean))

# %%
wordunique
# Out:
# ['offer',
#  'unshavable',
#  'childishly',
#  'dephlogistication',
#  'obsoletism',
#  'arracach',
#  'antireligious',
#  'conominee',
#  'pluminess',
#  'simeon',
#  'tabernacler',
#  'triticality',
#  'unceasing',
#  'reactualization',
#  'icelander',
#  'semisimious',
#  'concubinal',
#  'compassivity',
#  'zoarces',
#  'anthophora',
#  'glassless',
#  'witjar',
#  'herbivority',
#  'bicyanide',
#  'wiry',
#  'alchemist',
#  'metacentricity',
#  'octic',
#  'socratize',
#  'highish',
#  'tetrabiblos',
#  'determinativeness',
#  'paramedian',
#  'intercrop',
#  'myrmecobius',
#  'foreigneering',
#  'isonomous',
#  'vetusty',
#  'loka',
#  'iterativeness',
#  'fibromyitis',
#  'palilogy',
#  'autostylism',
#  'ariel',
#  'vas',
#  'comtism',
#  'gimlet',
#  'marmoric',
#  'servileness',
#  'scholar',
#  'superabduction',
#  'unaccommodating',
#  'gonolobus',
#  'silicomagnesian',
#  'scarecrowish',
#  'sonance',
#  'bobwood',
#  'chessel',
#  'adolescence',
#  'interosculant',
#  'mycetoid',
#  'rephase',
#  'matamoro',
#  'ubiquarian',
#  'anomalousness',
#  'supplicative',
#  'linguatula',
#  'unhex',
#  'fay',
#  'stampedingly',
#  'mongrelism',
#  'uninterred',
#  'firlot',
#  'authenticity',
#  'oxyhydric',
#  'stelliscript',
#  'dicky',
#  'familiarly',
#  'synecphonesis',
#  'pernettia',
#  'doricism',
#  'cochlidiid',
#  'punitiveness',
#  'meconin',
#  'catcall',
#  'synkinetic',
#  'preeze',
#  'immechanical',
#  'gavotte',
#  'monotone',
#  'spermaduct',
#  'physiotherapist',
#  'grillroom',
#  'impressionality',
#  'trichobranchiate',
#  'canebrake',
#  'nonresidenter',
#  'salsolaceae',
#  'opinability',
#  'cyanin',
#  'crazily',
#  'michelangelism',
#  'saburral',
#  'bricklayer',
#  'androgenesis',
#  'endosmometer',
#  'octennial',
#  'paranymph',
#  'manifold',
#  'chylaceous',
#  'compatibleness',
#  'woibe',
#  'unconfoundedly',
#  'unqualifying',
#  'invecked',
#  'paroptic',
#  'sold',
#  'incorrespondence',
#  'amphimictical',
#  'luminarious',
#  'unidentified',
#  'paragonimus',
#  'metroscirrhus',
#  'crucian',
#  'supervisor',
#  'bratticing',
#  'nonconformist',
#  'beaverwood',
#  'notodontid',
#  'restorationer',
#  'myrmecophobic',
#  'acrochordon',
#  'ulnae',
#  'babite',
#  'incorporative',
#  'eguttulate',
#  'unsweltered',
#  'enneahedria',
#  'kirtle',
#  'hypogenetic',
#  'unloathsome',
#  'honorous',
#  'prevalescence',
#  'wenchlike',
#  'retrusion',
#  'trumperiness',
#  'koryak',
#  'keratoplasty',
#  'achar',
#  'holosteous',
#  'oversilence',
#  'subconstable',
#  'apomictic',
#  'diabetogenic',
#  'inofficiosity',
#  'peakedly',
#  'pilferage',
#  'violinmaker',
#  'prophetically',
#  'antiprime',
#  'pawnshop',
#  'portunus',
#  'postaortic',
#  'moslemite',
#  'routivarite',
#  'trawl',
#  'semiaxis',
#  'spiceable',
#  'contracter',
#  'bentwood',
#  'etcher',
#  'gaetulian',
#  'inscribe',
#  'ahuatle',
#  'seropurulent',
#  'unscrewing',
#  'hydracrylic',
#  'biopsychological',
#  'ganzie',
#  'acquirement',
#  'composograph',
#  'semicoagulated',
#  'segregable',
#  'ibota',
#  'healthcraft',
#  'unambiguously',
#  'freethinking',
#  'nondefaulting',
#  'snorting',
#  'periplus',
#  'jacana',
#  'arthrosyrinx',
#  'epaulement',
#  'antinegro',
#  'promachinery',
#  'killifish',
#  'shigram',
#  'reprehensibly',
#  'limpiness',
#  'aldebaranium',
#  'fourble',
#  'desmidiaceous',
#  'karagan',
#  'gressorious',
#  'kmet',
#  'wonky',
#  'prolificacy',
#  'temperer',
#  'hula',
#  'unsanitary',
#  'bikram',
#  'lapidist',
#  'dilator',
#  'universanimous',
#  'sarcotic',
#  'unbegrudged',
#  'precedentary',
#  'filicauline',
#  'pyloroplasty',
#  'ditrematous',
#  'pentachenium',
#  'rupia',
#  'starringly',
#  'notebook',
#  'purlicue',
#  'companionate',
#  'bronchopleurisy',
#  'coadjustment',
#  'rinser',
#  'underliner',
#  'baryton',
#  'applaudable',
#  'marvelously',
#  'lunkhead',
#  'piscine',
#  'hybrid',
#  'protodont',
#  'quarrelingly',
#  'autocriticism',
#  'stretcherman',
#  'agapeti',
#  'rondelle',
#  'papolatry',
#  'sawfly',
#  'doughtiness',
#  'podotheca',
#  'seminarcosis',
#  'euclideanism',
#  'brockage',
#  'impressionability',
#  'rattletrap',
#  'disavowment',
#  'abusefulness',
#  'monarchianist',
#  'kabaya',
#  'pronouncement',
#  'youthhood',
#  'lettuce',
#  'sluttish',
#  'ergatandromorph',
#  'inofficial',
#  'toilsome',
#  'sternohumeral',
#  'tautit',
#  'unhoodwink',
#  'gubernaculum',
#  'cellulifugal',
#  'ocracy',
#  'newari',
#  'unjointed',
#  'commenter',
#  'castellated',
#  'franklandite',
#  'mammock',
#  'regimentation',
#  'thermosynthesis',
#  'enlivening',
#  'spiculation',
#  'tulle',
#  'underroast',
#  'venenousness',
#  'ecrustaceous',
#  'vertebrarterial',
#  'checked',
#  'phagocyter',
#  'alchornea',
#  'lissoflagellate',
#  'noninformative',
#  'preremunerate',
#  'pentacrinidae',
#  'paint',
#  'bananalander',
#  'adjurer',
#  'saithe',
#  'dysphonia',
#  'perfume',
#  'inobedient',
#  'pestiduct',
#  'tuberculinization',
#  'renascency',
#  'uncontaminate',
#  'instance',
#  'neurorthoptera',
#  'recommittal',
#  'tripylarian',
#  'johnnydom',
#  'bootboy',
#  'monkliness',
#  'perseverate',
#  'quakerishly',
#  'equilibrial',
#  'nonintermittent',
#  'microclastic',
#  'definement',
#  'myrothamnaceous',
#  'familistical',
#  'techiness',
#  'brahmic',
#  'nonsubscription',
#  'frazer',
#  'unlid',
#  'extrapolate',
#  'pretyrannical',
#  'barringtonia',
#  'hearthman',
#  'harelda',
#  'archprelatical',
#  'hydatopyrogenic',
#  'larrup',
#  'pleadableness',
#  'wheedlesome',
#  'overcrowd',
#  'buddleia',
#  'ironbark',
#  'cryptolunatic',
#  'zygopteron',
#  'paedotrophy',
#  'chamber',
#  'pteropod',
#  'nonchalantness',
#  'analyzable',
#  'barehanded',
#  'anatox',
#  'hairspring',
#  'misquality',
#  'spree',
#  'orca',
#  'unvacillating',
#  'elderliness',
#  'strived',
#  'gearksutite',
#  'expressivity',
#  'transferal',
#  'undesert',
#  'undesiring',
#  'turkeydom',
#  'autoagglutination',
#  'central',
#  'aposteme',
#  'bhaiyachara',
#  'coronion',
#  'overrash',
#  'deoxidator',
#  'aeolodicon',
#  'nonutilized',
#  'bungy',
#  'loge',
#  'tenoplastic',
#  'luther',
#  'japaconine',
#  'trilinguar',
#  'gyges',
#  'bactericidin',
#  'casamarca',
#  'laxation',
#  'attitudinize',
#  'coannex',
#  'candidature',
#  'dermatologist',
#  'knosp',
#  'prosperously',
#  'pseudoseptate',
#  'semifinished',
#  'fitchet',
#  'tracklessness',
#  'coppersmith',
#  'protanomal',
#  'flax',
#  'recontest',
#  'xicak',
#  'interapplication',
#  'consenter',
#  'gorkiesque',
#  'spondylotherapist',
#  'jivaran',
#  'lituoline',
#  'prosopantritis',
#  'undeclare',
#  'exculpatory',
#  'jurat',
#  'knitter',
#  'greenwort',
#  'unbelieffulness',
#  'clinocephalic',
#  'uninhabitably',
#  'introducee',
#  'postfixal',
#  'formicariae',
#  'philosoph',
#  'gonophorous',
#  'portension',
#  'trackingscout',
#  'otosalpinx',
#  'inordinateness',
#  'preceptist',
#  'noncirculation',
#  'seeking',
#  'tubig',
#  'nonpresentation',
#  'oxygenant',
#  'curiosa',
#  'penda',
#  'pyrrhus',
#  'induvial',
#  'umpqua',
#  'scrupulum',
#  'unlist',
#  'winona',
#  'infrarimal',
#  'fatbrained',
#  'intrabiontic',
#  'unstationed',
#  'bloodshedder',
#  'cyanean',
#  'boodledom',
#  'lumberdar',
#  'hardfist',
#  'kanara',
#  'semifit',
#  'piddle',
#  'joule',
#  'composer',
#  'rumple',
#  'paquet',
#  'blinkingly',
#  'cumshaw',
#  'credently',
#  'raya',
#  'mistreatment',
#  'sprang',
#  'axolemma',
#  'westaway',
#  'thermotactic',
#  'anthocarpous',
#  'aeronaut',
#  'scoterythrous',
#  'dreamtide',
#  'underprincipal',
#  'atoke',
#  'archaeogeology',
#  'cotterite',
#  'disconnecter',
#  'peasantize',
#  'dispenser',
#  'slight',
#  'septembrian',
#  'superdistribution',
#  'torpidness',
#  'totyman',
#  'upcanyon',
#  'tropidoleptus',
#  'sluggardize',
#  'atrip',
#  'soakman',
#  'mutability',
#  'pumpkinify',
#  'shovelbill',
#  'suspensorial',
#  'mitanni',
#  'immarcescible',
#  'thoo',
#  'unreclined',
#  'diplopodic',
#  'untipped',
#  'keelson',
#  'florification',
#  'palermitan',
#  'emigratory',
#  'unecstatic',
#  'bifacial',
#  'clinometric',
#  'scyphistomae',
#  'cytologically',
#  'marquisship',
#  'otariine',
#  'tourism',
#  'appositely',
#  'cider',
#  'fulgoridae',
#  'floodage',
#  'pyromellitic',
#  'psiloceran',
#  'combater',
#  'retroflection',
#  'hinderfully',
#  'apprehend',
#  'shortsighted',
#  'anabrotic',
#  'joyfully',
#  'opinionately',
#  'quaedam',
#  'norwestward',
#  'sustentor',
#  'toxicophidia',
#  'trusion',
#  'formol',
#  'bilch',
#  'truancy',
#  'athymic',
#  'regurge',
#  'colpeo',
#  'preterminal',
#  'ectoblastic',
#  'deaconal',
#  'unwontedly',
#  'freeboard',
#  'usuriously',
#  'trepidation',
#  'saxten',
#  'nonrecovery',
#  'semiacid',
#  'orcharding',
#  'executorial',
#  'padstone',
#  'tripersonally',
#  'caryopilite',
#  'dollbeer',
#  'dermahemia',
#  'whame',
#  'nonsimplification',
#  'aftertouch',
#  'redye',
#  'entomophthorales',
#  'incredible',
#  'pose',
#  'definiteness',
#  'birr',
#  'drug',
#  'coccidiomorpha',
#  'parasynetic',
#  'corruptingly',
#  'protometal',
#  'feedman',
#  'aliturgical',
#  'heedful',
#  'inspirability',
#  'redetermine',
#  'cragged',
#  'sorcerous',
#  'emetology',
#  'barbulate',
#  'histoplasmin',
#  'floriferous',
#  'phthisicky',
#  'ovibovine',
#  'heliothis',
#  'anaglyphy',
#  'hydrometeorological',
#  'lemography',
#  'idiomelon',
#  'teutophil',
#  'rhombohedron',
#  'oncometer',
#  'mammonitish',
#  'unicostate',
#  'extraclassroom',
#  'pyonephrosis',
#  'moniliaceae',
#  'matzos',
#  'vatic',
#  'paranete',
#  'copulative',
#  'diminishingly',
#  'pacifyingly',
#  'gelose',
#  'undivinable',
#  'grieve',
#  'ghoulery',
#  'discoblastula',
#  'flippantly',
#  'pangolin',
#  'mandil',
#  'nasioinial',
#  'fordableness',
#  'leonora',
#  'transgressional',
#  'intracerebrally',
#  'magnetograph',
#  'modification',
#  'flecker',
#  'subflexuose',
#  'shaveweed',
#  'uncallower',
#  'ensorcell',
#  'hippogriffin',
#  'holocephala',
#  'chebulinic',
#  'clericate',
#  'studwork',
#  'bosn',
#  'upstroke',
#  'scolophore',
#  'cronstedtite',
#  'pseudoacromegaly',
#  'myxorrhea',
#  'redcap',
#  'uronology',
#  'filionymic',
#  'wingle',
#  'corynebacterium',
#  'viable',
#  'wallow',
#  'forceful',
#  'catalanganes',
#  'descry',
#  'hendecacolic',
#  'shortschat',
#  'overbuild',
#  'coprolagnist',
#  'faviform',
#  'tubal',
#  'habitably',
#  'remeet',
#  'kniaz',
#  'desmoncus',
#  'unimitableness',
#  'adrenolysis',
#  'manucapture',
#  'anhedron',
#  'oneiromancy',
#  'nonage',
#  'dubbah',
#  'wirable',
#  'caneology',
#  'tenophyte',
#  'coafforest',
#  'overbrained',
#  'postuterine',
#  'hippocampi',
#  'isethionate',
#  'uncompoundedly',
#  'arthrotomy',
#  'behusband',
#  'sabbatism',
#  'yachtsmanship',
#  'reinsure',
#  'miscellaneous',
#  'reappointment',
#  'tickey',
#  'inexacting',
#  'peptidase',
#  'reluctantly',
#  'yoghurt',
#  'unusurious',
#  'aerobate',
#  'unbreakably',
#  'modificative',
#  'oldster',
#  'heliographically',
#  'begnaw',
#  'oncostman',
#  'snooperscope',
#  'precomment',
#  'zwieback',
#  'alfa',
#  'amarantus',
#  'ethanoyl',
#  'almuce',
#  'intense',
#  'lamellicornate',
#  'odontophoridae',
#  'optate',
#  'prededuct',
#  'sorehead',
#  'streetside',
#  'receptivity',
#  'oversaucy',
#  'cossnent',
#  'diffusate',
#  'nothingarianism',
#  'unpostulated',
#  'haematoxylon',
#  'absinthe',
#  'pleurocarpous',
#  'funicule',
#  'sung',
#  'gazelline',
#  'unplainly',
#  'overdubbed',
#  'kuskite',
#  'diomedea',
#  'atom',
#  'codify',
#  'resoutive',
#  'lityerses',
#  'satisfy',
#  'pugmiller',
#  'nosologist',
#  'amacrinal',
#  'dismalness',
#  'kreis',
#  'stenchful',
#  'suppressionist',
#  'siderostatic',
#  'osteologic',
#  'peakyish',
#  'cellulitis',
#  'caesarotomy',
#  'decussately',
#  'contrastive',
#  'turkishness',
#  'achate',
#  'cravat',
#  'unexecuted',
#  'bleeding',
#  'calorigenic',
#  'fumistery',
#  'acidiferous',
#  'encrinic',
#  'premorning',
#  'facetious',
#  'hardhack',
#  'enfonced',
#  'overrefinement',
#  'totchka',
#  'intracapsular',
#  'postponement',
#  'unfettled',
#  'goethian',
#  'yank',
#  'equispatial',
#  'antiglare',
#  'sinder',
#  'prewhip',
#  'dezincation',
#  'scrubbly',
#  'corrected',
#  'multiply',
#  'condonable',
#  'dataria',
#  'mexican',
#  'aminosuccinamic',
#  'diprotodontia',
#  'antechamber',
#  'puddee',
#  'superuniverse',
#  'lyreflower',
#  'penta',
#  'chiasmodontidae',
#  'embowment',
#  'glossless',
#  'haddie',
#  'multilobular',
#  'discriminable',
#  'jubilantly',
#  'quinaldic',
#  'cyclone',
#  'subjectibility',
#  'vamoose',
#  'anabathmos',
#  'subturriculate',
#  'corolliferous',
#  'magistrand',
#  'unsheathing',
#  'sophomorically',
#  'unlordly',
#  'bistate',
#  'heptameron',
#  'vachette',
#  'heroology',
#  'pseudogenerous',
#  'supposer',
#  'arikara',
#  'lipothymy',
#  'touchy',
#  'unflank',
#  'stalling',
#  'jalloped',
#  'sixtowns',
#  'uncheat',
#  'pinchcommons',
#  'cyperus',
#  'fourierian',
#  'allegorically',
#  'babbling',
#  'boce',
#  'nonculture',
#  'desperation',
#  'gutturotetany',
#  'parsley',
#  'thixle',
#  'imaginist',
#  'paleozoic',
#  'cumber',
#  'alpinely',
#  'hemipodan',
#  'hydroscopist',
#  'equilibrize',
#  'monal',
#  'arraignment',
#  'precipitative',
#  'recriminative',
#  'yankeeland',
#  'melilite',
#  'indogaean',
#  'iconometry',
#  'vauxite',
#  'flashover',
#  'rhynchopinae',
#  'yemenic',
#  'dinergate',
#  'cystosarcoma',
#  'brisken',
#  'aftercast',
#  'rareyfy',
#  'vegetation',
#  'greyly',
#  'mentzelia',
#  'unaccidental',
#  'refrigerator',
#  'stime',
#  'tregerg',
#  'tehuelchean',
#  'jacobin',
#  'fossilologist',
#  'nae',
#  'taffylike',
#  'unthaw',
#  'narcosynthesis',
#  'uncore',
#  'cytinus',
#  'reedition',
#  'drupiferous',
#  'africanthropus',
#  'silvicultural',
#  'ipid',
#  'bougainvillea',
#  'sickleweed',
#  'crystallography',
#  'manidae',
#  'perjinkities',
#  'quatrocentist',
#  'extratubal',
#  'graphium',
#  'terma',
#  'modifiably',
#  'oppositely',
#  'desilicate',
#  'unquieted',
#  'consensual',
#  'brownie',
#  'manatine',
#  'tarentala',
#  'unupbraidingly',
#  'waterward',
#  'abscessed',
#  'snowshoeing',
#  'peban',
#  'grittiness',
#  'nonstatutory',
#  'tethydan',
#  'shriver',
#  'reimbibe',
#  'tourer',
#  'trained',
#  'unal',
#  'multimillion',
#  'basally',
#  'septet',
#  'phototachometric',
#  'garlandless',
#  'pondgrass',
#  'ferrament',
#  'arnoseris',
#  'desinent',
#  'manscape',
#  'babyhouse',
#  'postilioned',
#  'sleighing',
#  'transliteration',
#  'revengement',
#  'rainbowweed',
#  'nayword',
#  'campaign',
#  'endopathic',
#  'nonacademic',
#  'bungarum',
#  'hypnone',
#  'alexanders',
#  'rosetty',
#  'carcinosarcoma',
#  'methylal',
#  'pentahydric',
#  'unkilled',
#  'antibacchic',
#  'bespray',
#  'visionize',
#  'rutuli',
#  'manistic',
#  'tahsil',
#  'unaccountability',
#  'fatherlessness',
#  'parchesi',
#  'unrubbish',
#  'illusioned',
#  'megatheroid',
#  'mooning',
#  'catastrophe',
#  'obturatory',
#  'anticrochet',
#  'hoplitic',
#  'quoniam',
#  'misrecognition',
#  'timberland',
#  'marketable',
#  'evaporative',
#  'synesis',
#  'creant',
#  'pompist',
#  'subovate',
#  'stilton',
#  'uncast',
#  'londonian',
#  'kenneth',
#  'objectification',
#  'incapsulate',
#  'psiloceras',
#  'constrain',
#  'bay',
#  'dewaterer',
#  'cubicalness',
#  'intermembral',
#  'gonochoristic',
#  'acerbas',
#  'unwarmable',
#  'myrtus',
#  'cataplasia',
#  'rainfall',
#  'pythagoreanize',
#  'undiatonic',
#  'cynebot',
#  'pretorsional',
#  'eaglestone',
#  'respective',
#  'alimony',
#  'ptyalolith',
#  'surmounted',
#  'anvasser',
#  'tubulodermoid',
#  'quinquenerval',
#  'belonoid',
#  'retold',
#  'paurometaboly',
#  'frieze',
#  'swashbuckle',
#  'unforeshortened',
#  'holocephalan',
#  'enthusiasm',
#  'verascope',
#  'reticulation',
#  'uneternal',
#  'misencourage',
#  'creativity',
#  'uncap',
#  'planetabler',
#  'hydrophis',
#  'moguey',
#  'latron',
#  'ibilao',
#  'monoethanolamine',
#  'visuoauditory',
#  'orchard',
#  'hydragogy',
#  'thung',
#  'chimonanthus',
#  'individualization',
#  'phylloclad',
#  'stavers',
#  'outfoot',
#  'undepravedness',
#  'bradypepsia',
#  'shoebinding',
#  'smouser',
#  'ungreat',
#  'potamophilous',
#  'untrekked',
#  'protopterous',
#  'mnemotechnist',
#  'unfermented',
#  'muckender',
#  ...]

# %%
wordunique.sort()

# %%
wordunique[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
wordclean = [word.strip().lower() for word in open('words','r')]

# %%
wordclean[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
wordclean = sorted(list(set([word.strip().lower() for word in open('words','r')])))

# %%
wordclean[:10]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic']

# %%
sorted('loves')
# Out:
# ['e', 'l', 'o', 's', 'v']

# %%
''.join(sorted('loves'))
# Out:
# 'elosv'

# %%
def signature(word)
